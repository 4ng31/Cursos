# %%
# %matplotlib inline

# imports go here
import numpy as np
import matplotlib.pyplot as plt

def BayesDL(X_train,Y_train,X_test)
    np.unique([1, 1, 2, 2, 3, 3])
    Nfeatures=X_train.shape[1]
    Ntrain=X_train.shape[0]
    classes=np.unique(Y_train) 
    Nclass=len(classes);  
    Ntest=X_test.shape[0]
    Pprio=np.zeros(len(Nclass))
    
    for i in range(1,Nclass,1):
        Pprio[i]=len(find(Ytrain==classes[i]))/ntrain;

    mean_classes=np.zeros((Nclass,Nfeatures));
    Xtrain_classes=np.zeros(Ntrain,Nfeatures,Nclass);

#    for i=1:ntrain
#        Xtrain_clases(i,:,clases==Ytrain_total(i))=Xtrain_total(i,:);
#    
#    Cov_general=nancov(Xtrain_total);%Esto lo usaremos para el discriminante lineal
#
#    for i=1:cant_clases
#        for j=1:features
#            Medias_clase(i,j)=nanmean(Xtrain_clases(:,j,i));
#    
#   prob_clases_lin=NaN(ntest,cant_clases);
#    for i_test=1:ntest
#        for i_clase=1:cant_clases
#        prob_clases_lin(:,i_clase)=mvnpdf(Xtest,Medias_clase(i_clase,:),Cov_general);
#
#    labels=(prob_clases_lin(:,1)./prob_clases_lin(:,2))*(Prob_a_priori(1)/Prob_a_priori(2));
#
#    for i=1:ntest
#
#        if labels(i)>=1
#            labels(i)=clases(1);
#        else
#           labels(i)=clases(2);
# Out:
# [ 3.24666657 -1.02814929 -9.60740441 -7.85758675 -2.02371603]
# [ 4.52881532  1.55983622 -5.71358214 -9.79265389 -5.26461991]
# [-0.99002567 -2.41044805 -8.1353097  -5.04809125 -2.068614  ]
# [ 2.3242785   0.50850342 -5.61171092 -8.16471907 -4.78988912]
# [-3.49252507 -2.2498346  -5.31158339 -3.87714828 -3.56078388]
# [  6.49308243   2.75156818  -5.29438533 -11.37065342  -6.0700843 ]
# [  5.17106695  -0.28578431 -10.04707483  -9.19096943  -2.1750633 ]
# [-0.78601803 -0.86630395 -5.25102913 -5.92216712 -4.28282634]
# [  1.00481683  -3.07393941 -11.45713492  -5.71376682  -0.07595571]
# [ 3.97153798  1.36829108 -5.53939508 -9.41824264 -5.25594087]
# [-1.73343727 -3.47586063 -9.52272324 -4.14367916 -0.84220094]
# [-0.79218769 -2.33519734 -8.18264624 -5.1846356  -2.08257108]
# [ 0.99815752 -1.1376338  -7.57786439 -6.67858997 -2.98374378]
# [ 1.88738431 -0.86517078 -7.92216512 -7.25943488 -2.94782493]
# [ 1.57225508  1.19148539 -3.49372356 -8.13019835 -6.19037379]
# ...
